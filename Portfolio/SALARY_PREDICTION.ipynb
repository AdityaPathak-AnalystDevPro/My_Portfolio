# %% [markdown]
# ### 1) Views About Problem Statement:
# * The problem statement provided revolves around the creation of a machine learning model to assist TechWorks Consulting in determining the salaries of newly hired employees. TechWorks Consulting is an IT staffing and consulting company known for its efficiency in matching highly skilled IT professionals with suitable job opportunities.
#
# * TechWorks Consulting's success is attributed to its ability to offer competitive compensation packages to its employees. This involves considering various factors like an employee's experience, Previuos job role, Graduation marks,performance and the market rate for the specific job and skill set. They also adapt salaries to align with current market trends and the cost of living in the employee's work location.
#
# * TechWorks Consulting evaluates employee performance, offering opportunities for salary increases based on contributions to the company. They aim to ensure that their compensation packages are not only competitive but also reflect the value each employee brings.
#
# * TechWorks Consulting's approach to determining salaries combines data-driven methods, market analysis, and performance assessment to provide fair and attractive compensation packages to their employees. The machine learning model being developed will further enhance this process by making accurate predictions based on historical data and relevant factors.

# %% [markdown]
# ### 2) Approach for Solving the task:
#
# 1) Understanding the Problem Statement: First step will be to get deep understanding of the problem statement provided by TechWorks Consulting. Analyze the data and the key factors mentioned, such as experience, previous CTC and previous job history to determine how they relate to salary prediction.
#
# 2) Data Collection and Preprocessing:
#
# * Data Collection: The data which was provided by Internshala, compile that relevant data, including information of colleges, cities, roles, previous CTC, previous job change, graduation marks, experience (months), and CTC.
#
# * Data Preprocessing: To prepare the data for machine learning, perform various preprocessing tasks:
#    - Handling missing values: Deciding whether to remove or impute missing data.
#    - Handling outliers: Identifying and addressing outliers that could affect model predictions.
#    - Handling categorical variables: Converting categorical variables like college, city and Role into numerical values using        techniques like one-hot encoding.
#    - Normalization: Scaling the values of different features to the same range, so one feature does not dominate others.
#    - Feature selection: Choosing the most important features for the regression model.
#
# 3) Data Transformation:
#
# * College and City Categories: use the provided files to categorize colleges into tiers (Tier 1, Tier 2, Tier 3) and cities into metro and non-metro categories. This information would be used to create dummy variables.
#
# * Dummy Variables: create dummy variables for categorical features like "Role" ,"College" and "City".
#
# 4) Model Selection:
#
# - explored a variety of regression models, including:
# - Linear Regression
# - Ridge Regression
# - Lasso Regression
# - Decision Tree Regression
# - Random Forest Regression
# - Gradient Boosting Regression
# choose these models to evaluate their performance and select the one with the best accuracy.
#
# 5) Hyperparameter Tuning: For selected models, perform hyperparameter tuning using techniques like GridSearchCV or RandomizedSearchCV to optimize model performance.
#
# 6) Model Evaluation: Evaluate the selected model(s) using various metrics:
#
# * Mean Squared Error (MSE): To measure the average difference between predicted and actual salaries.
# * R-squared (R2) Score: To understand the proportion of variance in salary explained by the model.
# * AIC (Akaike Information Criterion): To assess model fit and parsimony.
#
# 7) Further Improvements:
#
# * To enhance model accuracy, explore advanced techniques like bagging, boosting, and ensemble methods.
# * Feature engineering: Continuously improve feature selection and engineering to enhance model performance.
# * Cross-validation: Ensure that the model generalizes well to unseen data.
# * Final Model Selection: After comprehensive testing and evaluation, I would select the model that demonstrates the best accuracy and suitability for TechWorks Consulting's needs.
#
# 8) Deployment: Once the best model is chosen, I would prepare it for deployment in a production environment, making it accessible for salary predictions.

# %% [markdown]
# ### 3) What were the available ML model options you had to perform this task?
#
# * Linear Regression:
#       Linear regression is a straightforward model that establishes a linear relationship between input features and                 the target variable (salary). It's a good starting point for regression tasks.
#
# * Ridge and Lasso Regression:
#       Ridge and Lasso are variations of linear regression that introduce regularization to prevent overfitting.         They         were used to handle potential multicollinearity in the dataset and to avoid overfitting.
#
# * Decision Tree Regression:
#       Decision trees can capture non-linear relationships in the data and are suitable for regression tasks.                         However,they may be prone to overfitting without proper regularization.
#
# * Random Forest Regression:
#       Random Forest is an ensemble method that combines multiple decision trees. It was chosen because it tends to provide           more accurate predictions and is less prone to overfitting compared to a single decision tree.
#
# * Gradient Boosting Regression:
#      Gradient Boosting is another ensemble method that sequentially builds decision trees to correct errors of                      previous trees. It was chosen for its ability to capture complex relationships in the data and produce high-quality            predictions.
#
# * Support Vector Regression (SVR):
#      SVR can handle non-linear relationships and is effective in high-dimensional spaces. However, it was not          selected      due to its complexity and the need for careful hyperparameter tuning.
#
# * K-Nearest Neighbors (KNN):
#      KNN can capture non-linear relationships and patterns in the data. However, it may not perform well on large                    datasets, and it wasn't chosen to avoid potential computational issues.
#
#    These are all options we have along with three boosting techniques gradient boost, XG Boost, Ada Boost.

# %% [markdown]
# ### 4) performance of the model & It's reason
# * Random Forest Regression Metrics:
#    - Mean Squared Error:49601549.62
#    - R-squared: 0.68
#    - AIC: 5650.81
#
# * The Random Forest Regression model outperforms the other models in terms of MSE, which measures the average squared difference between predicted and actual values. A lower MSE indicates better predictive performance.
#
# * The R-squared (R2) score of 0.68 for the Random Forest model also suggests that it explains a significant proportion of the variance in the target variable (CTC), making it a good fit for the data.
#
# * Possible reasons for Random Forest's superior performance:
#
#   * Ensemble of Decision Trees: Random Forest is an ensemble method that combines multiple decision trees. This ensemble            approach   often results in improved accuracy and reduced overfitting compared to a single decision tree.
#
#   * Robust to Outliers: Random Forests are less sensitive to outliers in the data, which can help improve predictive performance   in the presence of unusual data points.
#
#   * Handling Non-Linearity: Random Forests can capture complex non-linear relationships between features and the target variable,   making them suitable for regression tasks with intricate patterns.
#
#   * Feature Importance: Random Forests provide a measure of feature importance, which can help identify the most influential       features in predicting salary.

# %% [markdown]
# ### 5) Steps for further improvement:
#
#
# * Explore and create new features that may have a strong correlation with salary prediction.
#   Identify and remove any irrelevant or redundant features that might be adding noise to the model.
#
# * Fine-tune the hyperparameters of the Random Forest model using techniques like GridSearchCV or RandomizedSearchCV. Adjust       parameters like the number of trees (n_estimators), maximum depth (max_depth), and minimum samples per leaf                     (min_samples_leaf) to find the best combination.
#
# * Experiment with ensemble methods like Bagging and AdaBoost, which can further improve the model's performance by combining     multiple models.
#
# * Explore more advanced regression models like Support Vector Regression (SVR) or Neural Networks to check if they provide better accuracy.
#
# * Explore feature selection techniques to identify and keep only the most relevant features. Removing irrelevant features can     simplify the model and potentially improve performance.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("C:\\Users\Ajinkya\Desktop\DSI Material\ML case Study.csv",header = 0)

# %%
colleges = pd.read_csv("C:\\Users\Ajinkya\Desktop\DSI Material\Colleges.csv", header = 0)
cities = pd.read_csv("C:\\Users\Ajinkya\Desktop\DSI Material\cities.csv", header = 0)

# %%
data
# Out:
#                           College             City       Role  Previous CTC  \
# 0                     SVNIT Surat          Asansol    Manager       55523.0
# 1                      NIT Bhopal            Ajmer  Executive       57081.0
# 2                    IEM, Kolkata  Rajpur Sonarpur  Executive       60347.0
# 3               KIIT, Bhubaneswar            Ajmer  Executive       49010.0
# 4                             DTU         Durgapur  Executive       57879.0
# ...                           ...              ...        ...           ...
# 1584     BITS Pilani (Goa Campus)            Surat  Executive       61285.0
# 1585                 NIT Warangal  Rajpur Sonarpur  Executive       63140.0
# 1586    NIT Tiruchipally (Trichy)        Ahmedabad  Executive       44907.0
# 1587               IIIT Hyderabad         Durgapur  Executive       52054.0
# 1588  R.V. College of Engineering            Delhi    Manager       44353.0
#
# ...

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# ### Feature Engineering:

# %%
metro_city = cities["Metrio City"].tolist()
non_metro_city = cities["non-metro cities"].tolist()

for item in data.City:
    if item in metro_city:
        data["City"].replace(item, 1, inplace=True)
    elif item in non_metro_city:
        data["City"].replace(item, 0, inplace=True)

# %%
Tier1 = colleges["Tier 1"].tolist()
Tier2 = colleges["Tier 2"].tolist()
Tier3 = colleges["Tier 3"].tolist()

for item in data.College:
    if item in Tier1:
        data["College"].replace(item,1,inplace=True)
    elif item in Tier2:
        data["College"].replace(item,2,inplace=True)
    elif item in Tier3:
        data["College"].replace(item,3,inplace=True)

# %%
df = pd.get_dummies(data, columns=["Role", "College"])

# %%
df
# Out:
#       City  Previous CTC  Previous job change  Graduation Marks  EXP (Month)  \
# 0        0       55523.0                    3                66           19
# 1        0       57081.0                    1                84           18
# 2        0       60347.0                    2                52           28
# 3        0       49010.0                    2                81           33
# 4        0       57879.0                    4                74           32
# ...    ...           ...                  ...               ...          ...
# 1584     1       61285.0                    3                44           60
# 1585     0       63140.0                    1                44           24
# 1586     1       44907.0                    1                60           19
# 1587     0       52054.0                    2                67           29
# 1588     1       44353.0                    3                75           18
#
# ...

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
del df['College_3']
del df['Role_Manager']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1589 entries, 0 to 1588
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 1589 non-null   int64
#  1   Previous CTC         1589 non-null   float64
#  2   Previous job change  1589 non-null   int64
#  3   Graduation Marks     1589 non-null   int64
#  4   EXP (Month)          1589 non-null   int64
#  5   CTC                  1589 non-null   float64
#  6   Role_Executive       1589 non-null   uint8
#  7   College_1            1589 non-null   uint8
#  8   College_2            1589 non-null   uint8
# dtypes: float64(2), int64(4), uint8(3)
# memory usage: 79.3 KB

# %%
df.shape
# Out:
# (1589, 9)

# %%
df.describe()
# Out:
#               City  Previous CTC  Previous job change  Graduation Marks  \
# count  1589.000000   1589.000000          1589.000000       1589.000000
# mean      0.514160  55518.453744             2.528634         59.855255
# std       0.499957   6655.218445             1.123918         14.935139
# min       0.000000  36990.000000             1.000000         35.000000
# 25%       0.000000  50518.000000             2.000000         46.000000
# 50%       1.000000  55291.000000             3.000000         60.000000
# 75%       1.000000  60109.000000             4.000000         73.000000
# max       1.000000  77911.000000             4.000000         85.000000
#
#        EXP (Month)            CTC  Role_Executive    College_1    College_2
# count  1589.000000    1589.000000     1589.000000  1589.000000  1589.000000
# mean     39.044682   75353.278798        0.793581     0.363751     0.297042
# std      14.108875   12587.288237        0.404862     0.481230     0.457099
# ...

# %%
#Understanding the data by plots
sns.countplot(x="Previous job change", data = data)
# Out:
# <Axes: xlabel='Previous job change', ylabel='count'>

# %%
sns.countplot(x="Role", data = data)
# Out:
# <Axes: xlabel='Role', ylabel='count'>

# %%
sns.pairplot(data)

# %%
sns.boxplot(y="Previous CTC",  data=df)
# Out:
# <Axes: ylabel='Previous CTC'>

# %%
sns.boxplot(y="CTC",  data=df)
# Out:
# <Axes: ylabel='CTC'>

# %%
sns.boxplot(y="Graduation Marks",  data=df)
# Out:
# <Axes: ylabel='Graduation Marks'>

# %% [markdown]
# ## Define the feature matrix X and the target variable y

# %%
X = df.drop(['CTC'], axis=1)
y = df['CTC']

# %% [markdown]
# ## Split the data into training and testing sets

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# %%
y_test.shape
# Out:
# (318,)

# %%
# Linear Regression
linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
y_pred_linear = linear_reg.predict(X_test)

# %%
linear_reg.intercept_
# Out:
# 55873.07737231627

# %%
# Ridge Regression
ridge = Ridge()
ridge.fit(X_train, y_train)
y_pred_ridge = ridge.predict(X_test)

# %%
# Lasso Regression
lasso = Lasso()
lasso.fit(X_train, y_train)
y_pred_lasso = lasso.predict(X_test)

# %%
# Decision Tree Regression
decision_tree = DecisionTreeRegressor()
decision_tree.fit(X_train, y_train)
y_pred_dt = decision_tree.predict(X_test)

# %%
# Random Forest Regression
random_forest = RandomForestRegressor()
random_forest.fit(X_train, y_train)
y_pred_rf = random_forest.predict(X_test)

# %%
# Gradient Boosting Regression
gradient_boosting = GradientBoostingRegressor()
gradient_boosting.fit(X_train, y_train)
y_pred_gb = gradient_boosting.predict(X_test)

# %%
# Define the number of features
num_features = X_train.shape[1]

# Evaluate the models
def evaluate_model(y_true, y_pred, model_name, num_features):
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    # Calculate AIC
    n = len(y_true)
    residuals = y_true - y_pred
    sse = np.sum(residuals**2)
    aic = n * np.log(sse / n) + 2 * num_features
    
    print(f"{model_name} Metrics:")
    print(f"Mean Squared Error: {mse:.2f}")
    print(f"R-squared: {r2:.2f}")
    print(f"AIC: {aic:.2f}\n")

evaluate_model(y_test, y_pred_linear, "Linear Regression", num_features)
evaluate_model(y_test, y_pred_ridge, "Ridge Regression", num_features)
evaluate_model(y_test, y_pred_lasso, "Lasso Regression", num_features)
evaluate_model(y_test, y_pred_dt, "Decision Tree Regression", num_features)
evaluate_model(y_test, y_pred_rf, "Random Forest Regression", num_features)
evaluate_model(y_test, y_pred_gb, "Gradient Boosting Regression", num_features)
# Out:
# Linear Regression Metrics:
# Mean Squared Error: 74874093.28
# R-squared: 0.52
# AIC: 5781.76
#
# Ridge Regression Metrics:
# Mean Squared Error: 74844357.75
# R-squared: 0.52
# AIC: 5781.63
#
# Lasso Regression Metrics:
# Mean Squared Error: 74869166.09
# R-squared: 0.52
# AIC: 5781.74
#
# Decision Tree Regression Metrics:
# Mean Squared Error: 105301711.42
# R-squared: 0.32
# AIC: 5890.20
#
# Random Forest Regression Metrics:
# Mean Squared Error: 50334112.44
# R-squared: 0.68
# AIC: 5655.47
#
# Gradient Boosting Regression Metrics:
# Mean Squared Error: 56105187.29
# R-squared: 0.64
# AIC: 5689.99
